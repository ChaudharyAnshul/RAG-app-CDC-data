# %% [markdown]
# # Upload Data to Big Query in GCP

# %%
import configparser

# %%
config = configparser.ConfigParser()
config.read('configuration.properties')
# Out:
# ['configuration.properties']

# %% [markdown]
# ### Update report location

# %%
import os
import pandas as pd

# %%
data = pd.read_csv("../data/cdc_data.csv", sep="\t")

# %%
data
# Out:
#                                                  title  \
# 0    DASH YRBSS - HS Cigar Use (by total grade/sex/...
# 1    Graph of Tobacco Use 3 Months Before and Last ...
# 2    CDC Nutrition, Physical Activity, and Obesity ...
# 3    Nutrition, Physical Activity, and Obesity - Be...
# 4                                  Map of HS Cigar Use
# ..                                                 ...
# 235  PLACES: ZCTA Data (GIS Friendly Format), 2021 ...
# 236  Stroke Mortality Data Among US Adults (35+) by...
# 237  PLACES: Local Data for Better Health, ZCTA Dat...
# 238  PLACES: Place Data (GIS Friendly Format), 2021...
# 239                          Filtered View for BMI Viz
#
#                                                   link dataSetCode  \
# 0    https://data.cdc.gov/Youth-Risk-Behaviors/DASH...   bedg-mmpy
# 1    https://data.cdc.gov/Maternal-Child-Health/Gra...   mbvg-apdj
# 2    https://data.cdc.gov/Nutrition-Physical-Activi...   nxst-x9p4
# 3    https://data.cdc.gov/Nutrition-Physical-Activi...   hn4x-zwk7
# 4    https://data.cdc.gov/Youth-Risk-Behaviors/Map-...   a5cb-a2ww
# ..                                                 ...         ...
# 235  https://data.cdc.gov/500-Cities-Places/PLACES-...   9xb7-9z99
# 236  https://data.cdc.gov/Heart-Disease-Stroke-Prev...   ua33-yiiu
# 237  https://data.cdc.gov/500-Cities-Places/PLACES-...   fbbf-hgkc
# 238  https://data.cdc.gov/500-Cities-Places/PLACES-...   cj8b-94cj
# 239  https://data.cdc.gov/Behavioral-Risk-Factors/F...   9z6e-x5wg
#
#        dataSetType                                        description  \
# 0    Filtered View  2015-2017. High School Dataset – Including Sex...
# 1            Chart  2011.  Centers for Disease Control and Prevent...
# 2          Dataset  This dataset contains policy data for 50 US st...
# 3          Dataset  This dataset includes data on adult's diet, ph...
# 4              Map  2015-2017. High School Dataset – Including Sex...
# ..             ...                                                ...
# 235        Dataset  This dataset contains model-based ZIP Code Tab...
# 236        Dataset  2017 to 2019, 3-year average. Rates are age-st...
# 237        Dataset  This dataset contains model-based ZIP Code tab...
# 238        Dataset  This dataset contains model-based place (incor...
# 239  Filtered View  2011 to present. BRFSS combined land line and ...
#
#      updateDate
# 0    27/07/2023
# 1    27/07/2023
# 2    25/08/2023
# 3    07/12/2023
# 4    27/07/2023
# ..          ...
# 235  25/08/2023
# 236  24/08/2023
# 237  25/08/2023
# 238  25/08/2023
# 239  17/11/2023
#
# [240 rows x 6 columns]

# %%
def check_file_exists(report_name):
    loc = f'reports/{report_name}.html'
    file_path = f'../{loc}'
    if os.path.exists(file_path):
        return loc
    else:
        return None

# %%
data['reportLocation'] = data['dataSetCode'].apply(check_file_exists)

# %%
data
# Out:
#                                                  title  \
# 0    DASH YRBSS - HS Cigar Use (by total grade/sex/...
# 1    Graph of Tobacco Use 3 Months Before and Last ...
# 2    CDC Nutrition, Physical Activity, and Obesity ...
# 3    Nutrition, Physical Activity, and Obesity - Be...
# 4                                  Map of HS Cigar Use
# ..                                                 ...
# 235  PLACES: ZCTA Data (GIS Friendly Format), 2021 ...
# 236  Stroke Mortality Data Among US Adults (35+) by...
# 237  PLACES: Local Data for Better Health, ZCTA Dat...
# 238  PLACES: Place Data (GIS Friendly Format), 2021...
# 239                          Filtered View for BMI Viz
#
#                                                   link dataSetCode  \
# 0    https://data.cdc.gov/Youth-Risk-Behaviors/DASH...   bedg-mmpy
# 1    https://data.cdc.gov/Maternal-Child-Health/Gra...   mbvg-apdj
# 2    https://data.cdc.gov/Nutrition-Physical-Activi...   nxst-x9p4
# 3    https://data.cdc.gov/Nutrition-Physical-Activi...   hn4x-zwk7
# 4    https://data.cdc.gov/Youth-Risk-Behaviors/Map-...   a5cb-a2ww
# ..                                                 ...         ...
# 235  https://data.cdc.gov/500-Cities-Places/PLACES-...   9xb7-9z99
# 236  https://data.cdc.gov/Heart-Disease-Stroke-Prev...   ua33-yiiu
# 237  https://data.cdc.gov/500-Cities-Places/PLACES-...   fbbf-hgkc
# 238  https://data.cdc.gov/500-Cities-Places/PLACES-...   cj8b-94cj
# 239  https://data.cdc.gov/Behavioral-Risk-Factors/F...   9z6e-x5wg
#
#        dataSetType                                        description  \
# 0    Filtered View  2015-2017. High School Dataset – Including Sex...
# 1            Chart  2011.  Centers for Disease Control and Prevent...
# 2          Dataset  This dataset contains policy data for 50 US st...
# 3          Dataset  This dataset includes data on adult's diet, ph...
# 4              Map  2015-2017. High School Dataset – Including Sex...
# ..             ...                                                ...
# 235        Dataset  This dataset contains model-based ZIP Code Tab...
# 236        Dataset  2017 to 2019, 3-year average. Rates are age-st...
# 237        Dataset  This dataset contains model-based ZIP Code tab...
# 238        Dataset  This dataset contains model-based place (incor...
# 239  Filtered View  2011 to present. BRFSS combined land line and ...
#
#      updateDate          reportLocation
# 0    27/07/2023                    None
# 1    27/07/2023                    None
# 2    25/08/2023  reports/nxst-x9p4.html
# 3    07/12/2023  reports/hn4x-zwk7.html
# 4    27/07/2023                    None
# ..          ...                     ...
# 235  25/08/2023                    None
# 236  24/08/2023                    None
# 237  25/08/2023                    None
# 238  25/08/2023                    None
# 239  17/11/2023                    None
#
# [240 rows x 7 columns]

# %% [markdown]
# ### Embed the Title

# %%
from transformers import AutoTokenizer, AutoModel
import torch
import vertexai
from vertexai.language_models import TextGenerationModel

# %%
# vertex AI config
project = config['VertexAI']['project']
endpoint_id = config['VertexAI']['endpoint_id']
location = config['VertexAI']['location']
api_endpoint = config['VertexAI']['api_endpoint']
model_pretrained = config['VertexAI']['model_pretrained']

# %%
model_name = "dmis-lab/biobert-base-cased-v1.1"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)

# %%
vertexai.init(project=project, location=location)

# %%
parameters = {
  "max_output_tokens": 1024,
  "temperature": 0.9,
  "top_p": 1
}

# %%
model_llm = TextGenerationModel.from_pretrained(model_pretrained)

# %%
model_llm = model_llm.get_tuned_model(f"projects/{project}/locations/{location}/models/{endpoint_id}")

# %%
def generateKeywords(text):
  response = model_llm.predict(
    f""" Text:{text} \n\n what disease is being targeted? Return only the disease name as a single word. if you cant find any disease in the text return one important keyword in the text""",
    **parameters
  )
  name = response.text
  
  return name

# %%
data["keywords"] = data["title"].apply(generateKeywords)

# %%
def removeNoise(text):
  text = text.strip()
  if len(text) > 50:
    return None
  return text

# %%
data["keywords"] = data["keywords"].apply(removeNoise)

# %%
def generateEmbedding(text):
  if text is None:
    text = "None"
  inputs = tokenizer(text, padding=True, truncation=True, return_tensors="pt")
  with torch.no_grad():
    outputs = model(**inputs)
  embeddings = outputs.last_hidden_state.mean(dim=1)
  embeddings_list = embeddings.tolist()
  return embeddings_list[0]

# %%
data["embedding"] = data["keywords"].apply(generateEmbedding)

# %%
data
# Out:
#                                                  title  \
# 0    DASH YRBSS - HS Cigar Use (by total grade/sex/...
# 1    Graph of Tobacco Use 3 Months Before and Last ...
# 2    CDC Nutrition, Physical Activity, and Obesity ...
# 3    Nutrition, Physical Activity, and Obesity - Be...
# 4                                  Map of HS Cigar Use
# ..                                                 ...
# 235  PLACES: ZCTA Data (GIS Friendly Format), 2021 ...
# 236  Stroke Mortality Data Among US Adults (35+) by...
# 237  PLACES: Local Data for Better Health, ZCTA Dat...
# 238  PLACES: Place Data (GIS Friendly Format), 2021...
# 239                          Filtered View for BMI Viz
#
#                                                   link dataSetCode  \
# 0    https://data.cdc.gov/Youth-Risk-Behaviors/DASH...   bedg-mmpy
# 1    https://data.cdc.gov/Maternal-Child-Health/Gra...   mbvg-apdj
# 2    https://data.cdc.gov/Nutrition-Physical-Activi...   nxst-x9p4
# 3    https://data.cdc.gov/Nutrition-Physical-Activi...   hn4x-zwk7
# 4    https://data.cdc.gov/Youth-Risk-Behaviors/Map-...   a5cb-a2ww
# ..                                                 ...         ...
# 235  https://data.cdc.gov/500-Cities-Places/PLACES-...   9xb7-9z99
# 236  https://data.cdc.gov/Heart-Disease-Stroke-Prev...   ua33-yiiu
# 237  https://data.cdc.gov/500-Cities-Places/PLACES-...   fbbf-hgkc
# 238  https://data.cdc.gov/500-Cities-Places/PLACES-...   cj8b-94cj
# 239  https://data.cdc.gov/Behavioral-Risk-Factors/F...   9z6e-x5wg
#
#        dataSetType                                        description  \
# 0    Filtered View  2015-2017. High School Dataset – Including Sex...
# 1            Chart  2011.  Centers for Disease Control and Prevent...
# 2          Dataset  This dataset contains policy data for 50 US st...
# 3          Dataset  This dataset includes data on adult's diet, ph...
# 4              Map  2015-2017. High School Dataset – Including Sex...
# ..             ...                                                ...
# 235        Dataset  This dataset contains model-based ZIP Code Tab...
# 236        Dataset  2017 to 2019, 3-year average. Rates are age-st...
# 237        Dataset  This dataset contains model-based ZIP Code tab...
# 238        Dataset  This dataset contains model-based place (incor...
# 239  Filtered View  2011 to present. BRFSS combined land line and ...
#
#      updateDate          reportLocation     keywords  \
# 0    27/07/2023                    None    Cigar use
# 1    27/07/2023                    None  Tobacco Use
# 2    25/08/2023  reports/nxst-x9p4.html      Obesity
# 3    07/12/2023  reports/hn4x-zwk7.html      Obesity
# 4    27/07/2023                    None    Cigar use
# ..          ...                     ...          ...
# 235  25/08/2023                    None          GIS
# 236  24/08/2023                    None       Stroke
# 237  25/08/2023                    None         Data
# 238  25/08/2023                    None         None
# 239  17/11/2023                    None         None
#
#                                              embedding
# 0    [0.16420388221740723, -0.22693508863449097, -0...
# 1    [0.14029575884342194, -0.13101698458194733, -0...
# 2    [0.1107550710439682, 0.08884633332490921, -0.0...
# 3    [0.1107550710439682, 0.08884633332490921, -0.0...
# 4    [0.16420388221740723, -0.22693508863449097, -0...
# ..                                                 ...
# 235  [0.2590693235397339, -0.32744064927101135, -0....
# 236  [0.1883343905210495, 0.057887036353349686, -0....
# 237  [0.10181767493486404, -0.18418431282043457, -0...
# 238  [0.3534121513366699, -0.19157488644123077, -0....
# 239  [0.3534121513366699, -0.19157488644123077, -0....
#
# [240 rows x 9 columns]

# %% [markdown]
# ### Upload data to GCP

# %%
from google.cloud import bigquery

# %%
dataset_id = config['BigQuery']['dataset_id']
table_id = config['BigQuery']['table_id']

# %%
data_dict = data.to_dict(orient="records")

# %%
bq_client = bigquery.Client()

# %%
schema = [
  bigquery.SchemaField("title", "STRING"),
  bigquery.SchemaField("link", "STRING"),
  bigquery.SchemaField("dataSetCode", "STRING"),
  bigquery.SchemaField("dataSetType", "STRING"),
  bigquery.SchemaField("description", "STRING"),
  bigquery.SchemaField("updateDate", "STRING"),
  bigquery.SchemaField("reportLocation", "STRING"),
  bigquery.SchemaField("embedding", "FLOAT64", mode="REPEATED"),
  bigquery.SchemaField("keywords", "STRING")
]

# %%
table_ref = bq_client.dataset(dataset_id).table(table_id)

# %%
errors = bq_client.insert_rows_json(table_ref, data_dict)

# %%
errors
# Out:
# []
